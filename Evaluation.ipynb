# %%
# %%capture
# !pip install ipywidgets
# !pip install higra

import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import random as r

import h5py

import higra as hg
from higra import HorizontalCutExplorer,HorizontalCutNodes, CptHierarchy

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import sys
from cremi import Volume
from cremi.io import CremiFile
from cremi.evaluation import NeuronIds, Clefts, SynapticPartners

test = CremiFile('./Results_B_bn.hdf', 'r')
truth = CremiFile('../CREMI datasets/sample_B_20160501.hdf', 'r')

# %%
from IPython.display import clear_output

truth_neurons = truth.read_neuron_ids()
test_neurons = test.read_neuron_ids()
voi_splits=[]
voi_merges=[]
rands=[]

for i in range(125):
    truth_ids = Volume(truth_neurons.data[i], resolution=(40.0, 4.0, 4.0))
    test_ids = Volume(test_neurons.data[i], resolution=(40.0, 4.0, 4.0))
    neuron_ids_evaluation = NeuronIds(truth_ids)
    (voi_split, voi_merge) = neuron_ids_evaluation.voi(test_ids)
    adapted_rand = neuron_ids_evaluation.adapted_rand(test_ids)
    
    voi_splits.append(voi_split)
    voi_merges.append(voi_merge)
    rands.append(adapted_rand)

    print("Neuron IDs")
    print("==========")
    print("voi split   : " + str(voi_split))
    print("voi merge   : " + str(voi_merge))
    print("adapted RAND: " + str(adapted_rand))

voi_splits=np.array(voi_splits)
voi_merges=np.array(voi_merges)
rands=np.array(rands)
# Out:
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.8608649978323134
# voi merge   : 3.619903040233303
# adapted RAND: 0.8718614051373444
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2611284349799556
# voi merge   : 1.4093533863089946
# adapted RAND: 0.4739498359070541
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2458385251560766
# voi merge   : 1.5871870830388861
# adapted RAND: 0.5456257473789569
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5378402094608412
# voi merge   : 1.4620962596115108
# adapted RAND: 0.5904969371501929
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3267074518883337
# voi merge   : 1.4301547075053245
# adapted RAND: 0.4279311873557373
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.0786277259281496
# voi merge   : 2.21066800568108
# adapted RAND: 0.6625248055831137
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2999421179464572
# voi merge   : 2.1511129976625982
# adapted RAND: 0.6567351652228016
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5027228234582268
# voi merge   : 1.870236716623543
# adapted RAND: 0.6651916265294746
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.0421343363985727
# voi merge   : 2.6133614112274826
# adapted RAND: 0.7352533570757882
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.4533642030902438
# voi merge   : 1.554888572160573
# adapted RAND: 0.6192106188182277
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3502299530474862
# voi merge   : 1.5434447737265677
# adapted RAND: 0.5845388799231723
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.4219273979587956
# voi merge   : 1.3217941983925494
# adapted RAND: 0.5531951139515625
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2255500155728276
# voi merge   : 1.4767763834568501
# adapted RAND: 0.5504949536559944
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.9278351357800443
# voi merge   : 2.505133669940448
# adapted RAND: 0.663137048220668
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.5316058009913147
# voi merge   : 4.545857551225323
# adapted RAND: 0.8953831604666017
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.06917939884713782
# voi merge   : 5.948293288287709
# adapted RAND: 0.936930640658351
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.039037985106176294
# voi merge   : 5.582221017371642
# adapted RAND: 0.9266899550638682
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.8281831548039493
# voi merge   : 2.356857788348197
# adapted RAND: 0.7230280659291553
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2318063331884732
# voi merge   : 1.026946901522752
# adapted RAND: 0.39726778195425205
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3523623075062832
# voi merge   : 1.406219004965529
# adapted RAND: 0.5460204958018169
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.47677494697855
# voi merge   : 1.2893467698189118
# adapted RAND: 0.4647517114990841
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5175601957756115
# voi merge   : 0.8944518688169273
# adapted RAND: 0.32929979952878374
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3124682389807463
# voi merge   : 1.0272312238627244
# adapted RAND: 0.344394118343452
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.4364270980039542
# voi merge   : 1.341892598525551
# adapted RAND: 0.5065091093711644
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.675932433506593
# voi merge   : 0.9241001061673499
# adapted RAND: 0.36571066143523623
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3726375530128014
# voi merge   : 1.4610152166561343
# adapted RAND: 0.4493593917292894
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2881262124043602
# voi merge   : 1.1354966901356687
# adapted RAND: 0.33037342926737945
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.6545334144143136
# voi merge   : 1.1145683319051658
# adapted RAND: 0.40682609560315175
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3378618155986786
# voi merge   : 1.3414353475196454
# adapted RAND: 0.3592082941975946
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.6461704596980546
# voi merge   : 1.0078009297271813
# adapted RAND: 0.40135627141905983
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.334121889350323
# voi merge   : 1.9254557263580991
# adapted RAND: 0.59211476821088
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2517877967352993
# voi merge   : 0.9300486160127562
# adapted RAND: 0.24946286305932508
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3225757636201099
# voi merge   : 1.5546259731477206
# adapted RAND: 0.46589272956583505
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5603523456467154
# voi merge   : 1.0592721758913934
# adapted RAND: 0.4253271465899202
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2961027233955829
# voi merge   : 1.430058088710543
# adapted RAND: 0.46195817656656224
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.6345067788382652
# voi merge   : 0.9033196178087126
# adapted RAND: 0.33094265182590143
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.386957957393257
# voi merge   : 1.025233118848928
# adapted RAND: 0.3240606178859846
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.4511467199022998
# voi merge   : 0.9554855203613961
# adapted RAND: 0.3084236224593696
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5398379574360244
# voi merge   : 0.9456593917492074
# adapted RAND: 0.3311147927387469
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.4323613078389346
# voi merge   : 1.023898345584298
# adapted RAND: 0.35397217492869604
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.24794581740971
# voi merge   : 1.0995108813808
# adapted RAND: 0.35243932766176367
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.0672391334305944
# voi merge   : 1.407940308748215
# adapted RAND: 0.3974407159254424
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.0099733029581446
# voi merge   : 1.2534774783038454
# adapted RAND: 0.35369213254559473
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.8669588978097922
# voi merge   : 1.8347893662491073
# adapted RAND: 0.5396110071251374
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.03715246661546524
# voi merge   : 4.86406376736765
# adapted RAND: 0.876560262000232
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.22061191702438437
# voi merge   : 4.801827350796621
# adapted RAND: 0.8761640056066844
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.5911092118679943
# voi merge   : 3.7790206423611274
# adapted RAND: 0.8299306304254059
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.9881350054623809
# voi merge   : 1.647271863797537
# adapted RAND: 0.5609645033797656
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2892234368497388
# voi merge   : 0.860838966524181
# adapted RAND: 0.283431158598638
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3034031893324842
# voi merge   : 0.9793674687557079
# adapted RAND: 0.2949823405720462
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2160106577952738
# voi merge   : 1.8183680666704678
# adapted RAND: 0.6168187447967113
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.415020189680111
# voi merge   : 1.0810125808593696
# adapted RAND: 0.3606866566832011
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.448853532478489
# voi merge   : 1.3220481894864244
# adapted RAND: 0.5275256217108685
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3008977841950402
# voi merge   : 1.6911612054842686
# adapted RAND: 0.6215894225937013
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5782344503903478
# voi merge   : 1.3320069525276084
# adapted RAND: 0.4880892263822486
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.493238916206734
# voi merge   : 1.3513872628851866
# adapted RAND: 0.4938763044839588
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5976841255076162
# voi merge   : 1.2638584457721829
# adapted RAND: 0.5359090101613097
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.551061478414862
# voi merge   : 1.0626021880166105
# adapted RAND: 0.4066181461623667
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.6709798280155401
# voi merge   : 1.1323162355146652
# adapted RAND: 0.47543326806707553
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3343493385166894
# voi merge   : 1.4433885143563452
# adapted RAND: 0.4908084891903687
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3550830886951193
# voi merge   : 1.3428185954497551
# adapted RAND: 0.4482364392957383
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2811118859793447
# voi merge   : 1.6466229769042626
# adapted RAND: 0.5635450533257045
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.395357497090627
# voi merge   : 1.372833529850988
# adapted RAND: 0.3942870968301502
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.5285826536789728
# voi merge   : 4.705070195501404
# adapted RAND: 0.9071431104355954
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.4707516857699383
# voi merge   : 1.0712250277443103
# adapted RAND: 0.29098701556535833
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3826012570412898
# voi merge   : 1.230401799583447
# adapted RAND: 0.35638343108606085
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2875344886576714
# voi merge   : 1.2809485578209725
# adapted RAND: 0.44468712099652763
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3667884297868997
# voi merge   : 0.995641616434281
# adapted RAND: 0.345797817284644
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5962881000590834
# voi merge   : 1.1414566017676526
# adapted RAND: 0.4463722517676437
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.6142216437080468
# voi merge   : 1.0639039484626314
# adapted RAND: 0.42607083172053684
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.4068761510895653
# voi merge   : 1.1953045566377065
# adapted RAND: 0.42584549520111703
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5635340035370289
# voi merge   : 1.068134472867713
# adapted RAND: 0.40738665938324625
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.419951866752067
# voi merge   : 1.2544573991721408
# adapted RAND: 0.47112396232794607
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2482536513668374
# voi merge   : 1.96419000640754
# adapted RAND: 0.6409562438269695
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.0766577376880648
# voi merge   : 3.7235636438220214
# adapted RAND: 0.871432671838575
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3042545597099624
# voi merge   : 1.7405902809713452
# adapted RAND: 0.5922000215594607
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2916368807057197
# voi merge   : 1.619996285799721
# adapted RAND: 0.43689862255008505
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 0.5570253438632344
# voi merge   : 5.37709097278899
# adapted RAND: 0.9209451468483592
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2543650732632745
# voi merge   : 2.4999220140182676
# adapted RAND: 0.7667535846880945
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5625411239789175
# voi merge   : 1.2538249068762777
# adapted RAND: 0.4983921653543151
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.7040493863618051
# voi merge   : 1.1742545271899278
# adapted RAND: 0.4491344121201445
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.633048591329114
# voi merge   : 1.9827263414540444
# adapted RAND: 0.6436372892879214
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.6443481475138586
# voi merge   : 1.3279917301842987
# adapted RAND: 0.5226096952193827
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.719005150743652
# voi merge   : 1.3824326479589422
# adapted RAND: 0.570699124973179
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.7901417759563774
# voi merge   : 1.0831497033991253
# adapted RAND: 0.5225578304396392
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.8912513632311951
# voi merge   : 1.1477974888841973
# adapted RAND: 0.5470285873141971
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.8779263444467742
# voi merge   : 1.2376524648690017
# adapted RAND: 0.5762956581218552
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 2.011907079318733
# voi merge   : 1.0404625094764566
# adapted RAND: 0.558544302031289
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.8447276623278486
# voi merge   : 0.979798962669019
# adapted RAND: 0.5032846840843961
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.9419851074460577
# voi merge   : 1.0093230524641355
# adapted RAND: 0.5034454864446776
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.8669862352178976
# voi merge   : 1.17938805089671
# adapted RAND: 0.5165721737724343
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.7100039531651112
# voi merge   : 1.269065708671782
# adapted RAND: 0.5059970202053969
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.8174070016153192
# voi merge   : 1.3639604489225103
# adapted RAND: 0.5233456919456697
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.815013391830359
# voi merge   : 1.0709773130582971
# adapted RAND: 0.4500312810833703
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.6089890908654496
# voi merge   : 1.381465512933004
# adapted RAND: 0.402977650004417
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.900620692014788
# voi merge   : 1.0012658343131535
# adapted RAND: 0.43392880050062577
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.7692465487247022
# voi merge   : 1.014552906107624
# adapted RAND: 0.38167982567296244
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.759704875790699
# voi merge   : 1.0799265641174707
# adapted RAND: 0.35600628955978797
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5770364318323025
# voi merge   : 1.2452535745564945
# adapted RAND: 0.45557723483722556
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.6983745632513194
# voi merge   : 1.1401366615727433
# adapted RAND: 0.4490444358519674
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5928893284455286
# voi merge   : 1.302939913890063
# adapted RAND: 0.45963341490102827
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.735833253784751
# voi merge   : 1.1222091469162645
# adapted RAND: 0.47293874759239896
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.6935950893554947
# voi merge   : 1.169605642086635
# adapted RAND: 0.4522631562136331
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.8012806534609913
# voi merge   : 1.1411127531891445
# adapted RAND: 0.46581696832946706
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.6731763553038796
# voi merge   : 1.124499432771852
# adapted RAND: 0.4257606236063992
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.788845382293513
# voi merge   : 1.1190597073289037
# adapted RAND: 0.4203041621034732
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.6088564558927536
# voi merge   : 1.1176430947958704
# adapted RAND: 0.3793231246979004
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5978522095942815
# voi merge   : 1.0161851669543964
# adapted RAND: 0.3407864811164304
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5978207087259773
# voi merge   : 0.9718413661628154
# adapted RAND: 0.35474018475203584
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.372235544720008
# voi merge   : 1.8952537955936126
# adapted RAND: 0.5904406777650528
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.5440134105376484
# voi merge   : 1.0569374890101881
# adapted RAND: 0.3339965496207551
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.6452843227674847
# voi merge   : 1.0943654168928005
# adapted RAND: 0.3589723354426291
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3883477295607378
# voi merge   : 1.0324486529030164
# adapted RAND: 0.2257219222861071
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.4218412848265933
# voi merge   : 1.0163594748158393
# adapted RAND: 0.2045372139802607
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.4239057899157794
# voi merge   : 0.9700030180257221
# adapted RAND: 0.19247418802819571
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3304838613767223
# voi merge   : 1.1396559463385192
# adapted RAND: 0.21124491530645506
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.372805664086123
# voi merge   : 1.004330980379063
# adapted RAND: 0.1848536664773649
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.4239313828215454
# voi merge   : 1.0553740632258313
# adapted RAND: 0.17055718908013295
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.4640814005904157
# voi merge   : 1.1419562574184412
# adapted RAND: 0.2222333017400081
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.2972453097288326
# voi merge   : 1.2442791614722546
# adapted RAND: 0.21078788814103766
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3449536933456119
# voi merge   : 1.0021054072056206
# adapted RAND: 0.17662320316290403
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.327428867569139
# voi merge   : 0.8411869717035813
# adapted RAND: 0.15796420116310317
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.3584615188899756
# voi merge   : 0.8243550878136251
# adapted RAND: 0.15288868265281297
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.133771146480719
# voi merge   : 0.9704724075316873
# adapted RAND: 0.13860931076397498
# Computing VOI...
# Computing RAND...
# Neuron IDs
# ==========
# voi split   : 1.230504377486003
# voi merge   : 0.8902769649503312
# adapted RAND: 0.1490257360547329

# %%
print(f'voi split average over all slices : {np.mean(voi_splits)}')
print(f'voi merge average over all slices : {np.mean(voi_merges)}')
print(f'adapted RAND average over all slices : {np.mean(rands)}')
print(f'RAND average over all slices : {1-np.mean(rands)}')
print("Cremi SCORE : ", np.sqrt((np.mean(voi_splits)+np.mean(voi_merges))*(np.mean(rands))))
# Out:
# voi split average over all slices : 1.3796627988351924
# voi merge average over all slices : 1.5669055749017082
# adapted RAND average over all slices : 0.47351548993933623
# RAND average over all slices : 0.5264845100606638
# Cremi SCORE :  1.1812052180420562
